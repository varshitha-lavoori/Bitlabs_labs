# %%
#1. Read csv, excel and json file
import pandas as pd
df=pd.read_csv("Uber.csv")
df.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
data=pd.read_excel("Historicalinvesttemp.xlsx")
print(data.head())
# Out:
#   Unnamed: 0                        Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0        NaN                               NaN        NaN        NaN
# 1        NaN                               NaN        NaN        NaN
# 2        NaN                               NaN        NaN        NaN
# 3        NaN                               NaN        NaN        NaN
# 4        NaN  Annual Returns on Investments in        NaN        NaN

# %%
dff=pd.read_json("iris.json")
dff.head()
# Out:
#    sepalLength  sepalWidth  petalLength  petalWidth species
# 0          5.1         3.5          1.4         0.2  setosa
# 1          4.9         3.0          1.4         0.2  setosa
# 2          4.7         3.2          1.3         0.2  setosa
# 3          4.6         3.1          1.5         0.2  setosa
# 4          5.0         3.6          1.4         0.2  setosa

# %%
#2. load only first 100 rows
df=pd.read_csv("Uber.csv",nrows=100)
df
# Out:
#         START_DATE*        END_DATE* CATEGORY*       START*            STOP*  \
# 0    1/1/2016 21:11   1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1     1/2/2016 1:25    1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2    1/2/2016 20:25   1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3    1/5/2016 17:31   1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4    1/6/2016 14:42   1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
# ..              ...              ...       ...          ...              ...
# 95   2/12/2016 8:21   2/12/2016 8:42  Business         Cary           Durham
# 96  2/12/2016 10:45  2/12/2016 10:52  Business       Durham      Morrisville
# 97  2/12/2016 11:14  2/12/2016 11:35  Business  Morrisville          Raleigh
# 98  2/12/2016 13:02  2/12/2016 13:36  Business      Raleigh             Cary
# 99  2/12/2016 14:49  2/12/2016 15:06  Business         Cary      Morrisville
#
#     MILES*         PURPOSE*
# ...

# %%
#3. Display first 5 rows and last two columns
df.iloc[0:5,-2]
# Out:
# 0     5.1
# 1     5.0
# 2     4.8
# 3     4.7
# 4    63.7
# Name: MILES*, dtype: float64

# %%
#4. Display 50 to 100 rows
df.iloc[50:101]
# Out:
#         START_DATE*        END_DATE* CATEGORY*           START*  \
# 50  1/28/2016 12:28  1/28/2016 13:00  Business             Cary
# 51  1/28/2016 15:11  1/28/2016 15:31  Business  Meredith Townes
# 52  1/28/2016 16:21  1/28/2016 16:51  Business          Raleigh
# 53   1/29/2016 9:31   1/29/2016 9:45  Business             Cary
# 54  1/29/2016 10:56  1/29/2016 11:07  Business             Cary
# 55  1/29/2016 11:43  1/29/2016 12:03  Business             Cary
# 56  1/29/2016 13:24  1/29/2016 13:47  Business           Durham
# 57  1/29/2016 18:31  1/29/2016 18:52  Business             Cary
# 58  1/29/2016 21:21  1/29/2016 21:40  Business             Apex
# 59  1/30/2016 16:21  1/30/2016 16:33  Business             Cary
# 60  1/30/2016 18:09  1/30/2016 18:24  Business             Apex
# 61   2/1/2016 10:35   2/1/2016 11:15  Business             Cary
# 62   2/1/2016 12:10   2/1/2016 12:43  Business      Chapel Hill
# 63   2/1/2016 12:56   2/1/2016 13:07  Business       Northwoods
# ...

# %%
#5. Display all the rows from first 3 columns.
df.iloc[:,0:3]
# Out:
#         START_DATE*        END_DATE* CATEGORY*
# 0    1/1/2016 21:11   1/1/2016 21:17  Business
# 1     1/2/2016 1:25    1/2/2016 1:37  Business
# 2    1/2/2016 20:25   1/2/2016 20:38  Business
# 3    1/5/2016 17:31   1/5/2016 17:45  Business
# 4    1/6/2016 14:42   1/6/2016 15:49  Business
# ..              ...              ...       ...
# 95   2/12/2016 8:21   2/12/2016 8:42  Business
# 96  2/12/2016 10:45  2/12/2016 10:52  Business
# 97  2/12/2016 11:14  2/12/2016 11:35  Business
# 98  2/12/2016 13:02  2/12/2016 13:36  Business
# 99  2/12/2016 14:49  2/12/2016 15:06  Business
#
# [100 rows x 3 columns]

# %%
#6. Convert Object format to date format
df.dtypes
df['START_DATE*']=pd.to_datetime(df['START_DATE*'])
df.dtypes
# Out:
# START_DATE*    datetime64[ns]
# END_DATE*              object
# CATEGORY*              object
# START*                 object
# STOP*                  object
# MILES*                float64
# PURPOSE*               object
# dtype: object

# %%
#7. convert object to int, float formats.
df['STOP*'] = pd.to_numeric(df['STOP*'], errors='coerce').astype('Int64')
df['START**'] = pd.to_numeric(df['STOP*'], errors='coerce')
df.dtypes
# Out:
# START_DATE*    datetime64[ns]
# END_DATE*              object
# CATEGORY*              object
# START*                 object
# STOP*                   Int64
# MILES*                float64
# PURPOSE*               object
# START**                 Int64
# dtype: object
